# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import plotly.offline as pyo
import plotly.graph_objects as go
import seaborn as sns

# %%
spy_df=web.DataReader('SPY','yahoo')

# %%
spy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2015-10-16 to 2020-10-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1258 non-null   float64
#  1   Low        1258 non-null   float64
#  2   Open       1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Volume     1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
# dtypes: float64(6)
# memory usage: 68.8 KB

# %%
spy_df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    263.100668   260.271765   261.752687   261.790079  9.040269e+07
# std      39.875973    39.316906    39.630260    39.584776  4.941377e+07
# min     184.100006   181.020004   182.339996   182.860001  2.027000e+07
# 25%     227.487499   225.977501   226.732498   226.764999  5.849180e+07
# 50%     267.809998   264.309998   266.509995   266.164993  7.681920e+07
# 75%     290.817505   288.469994   289.839996   289.447510  1.036504e+08
# max     358.750000   353.429993   355.869995   357.700012  3.922207e+08
#
#          Adj Close
# count  1258.000000
# mean    250.415830
# std      44.324301
# min     166.733185
# 25%     211.185307
# 50%     254.252594
# 75%     281.182991
# max     356.273865

# %%
# Stock time frame
start=pd.to_datetime('2015-10-10')
end=pd.to_datetime('2020-10-15')

# %%
# One stock reader
ago=web.DataReader('AGO','yahoo',start,end)

# %%
# Visualization
ago.tail()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2020-10-08  29.330000  27.990000  29.200001  28.490000  1815400.0  28.490000
# 2020-10-09  28.750000  27.820000  28.450001  28.049999  1935300.0  28.049999
# 2020-10-12  28.559999  27.639999  27.889999  28.430000  1322400.0  28.430000
# 2020-10-13  28.500000  27.660000  28.280001  27.850000  1173100.0  27.850000
# 2020-10-14  27.950001  26.990000  27.740000  27.010000  1088300.0  27.010000

# %%
# Plot facebook
face['Close'].plot(label='AGO',figsize=(10,8))
spy_df['Close'].plot(label='SPY Index')
plt.legend();

# %%
# Compare cumulative return 
facebook['Cumulative']=facebook['Close']/facebook['Close'].iloc[0]
spy_df['Cumulative']=spy_df['Close']/spy_df['Close'].iloc[0]

# %%
# Plot cumulative return 
facebook['Cumulative'].plot(label='FB',figsize=(10,8))
spy_df['Cumulative'].plot(label='SPY')
plt.legend();

# %%
# Daily Return
facebook['Daily Return']=ago['Close'].pct_change(1)
spy_df['Daily Return']=spy_df['Close'].pct_change(1)

# %%
# Correlation
plt.scatter(ago['Daily Return'],spy_df['Daily Return'],alpha=0.25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0cb6f575c69c> in <module>
#       1 # Correlation
# ----> 2 plt.scatter(ago['Daily Return'],spy_df['Daily Return'],alpha=0.25)
#
# c:\python\python385\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2872         verts=cbook.deprecation._deprecated_parameter,
#    2873         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2874     __ret = gca().scatter(
#    2875         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2876         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# c:\python\python385\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\python\python385\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\python\python385\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
# Calculate beta,alpha,r_value,p_value and std value
beta,alpha,r_value,p_value,std_err=stats.linregress(facebook['Daily Return'].iloc[1:],spy_df['Daily Return'].iloc[1:])

# %%
beta

# %%
alpha

# %%
# Create an artifial noise to improve our beta
noise=np.random.normal(0,0.001,len(spy_df['Daily Return'].iloc[1:]))

# %%
noise

# %%
# fake stock
fake_stock=spy_df['Daily Return'].iloc[1:]+noise

# %%
fake_stock

# %%
# plot
plt.scatter(fake_stock,spy_df['Daily Return'].iloc[1:],alpha=0.25)

# %%
beta,alpha,r_value,p_value,std_err=stats.linregress(fake_stock,spy_df['Daily Return'].iloc[1:])

# %%
beta

# %%
alpha

# %%
#correlation matrix
corrmat =spy_df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#scatterplot
sns.set()
cols = ['High', 'Low', 'Open', 'Volume', 'Adj Close', 'Cumulative', 'Daily Return']
sns.pairplot(spy_df[cols], size = 2.5)
plt.show();

# %%
#histogram and normal probability plot
sns.distplot(spy_df['Close'], fit=norm);
fig = plt.figure()
res = stats.probplot(spy_df['C'], plot=plt)
